# %%
# Out:
# /var/folders/g0/nsxm0s0x64z69dg0l2b9mf4m0000gn/T/ipykernel_99766/14507977.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(tickers, start="2005-01-01", end="2024-01-01", interval="1d")
# [*********************100%***********************]  6 of 6 completed
